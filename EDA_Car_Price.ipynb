# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('Car_Price_Cleaned.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  symboling  normalized_losses Fuel_type make num_of_doors  \
# 0           0          3              115.0       gas  std          two
# 1           1          3              115.0       gas  std          two
# 2           2          1              115.0       gas  std          two
# 3           3          2              164.0       gas  std         four
# 4           4          2              164.0       gas  std         four
#
#     aspiration wheel_base engine_location  drive_wheels  ... engine_size  \
# 0  convertible        rwd           front          88.6  ...         130
# 1  convertible        rwd           front          88.6  ...         130
# 2    hatchback        rwd           front          94.5  ...         152
# 3        sedan        fwd           front          99.8  ...         109
# 4        sedan        4wd           front          99.4  ...         136
#
#    fuel_system  bore  stroke  compression_ratio horsepower peak_rpm  city_mpg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 27 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         201 non-null    int64
#  1   symboling          201 non-null    int64
#  2   normalized_losses  201 non-null    float64
#  3   Fuel_type          201 non-null    object
#  4   make               201 non-null    object
#  5   num_of_doors       201 non-null    object
#  6   aspiration         201 non-null    object
#  7   wheel_base         201 non-null    object
#  8   engine_location    201 non-null    object
#  9   drive_wheels       201 non-null    float64
#  10  body_style         201 non-null    object
#  11  length             201 non-null    float64
#  12  width              201 non-null    float64
#  13  height             201 non-null    float64
#  14  curb_weight        201 non-null    int64
#  15  engine_type        201 non-null    object
# ...

# %%
df_cat = df.select_dtypes(include='O')

# %%
df_cat
# Out:
#     Fuel_type   make num_of_doors   aspiration wheel_base engine_location  \
# 0         gas    std          two  convertible        rwd           front
# 1         gas    std          two  convertible        rwd           front
# 2         gas    std          two    hatchback        rwd           front
# 3         gas    std         four        sedan        fwd           front
# 4         gas    std         four        sedan        4wd           front
# ..        ...    ...          ...          ...        ...             ...
# 196       gas    std         four        sedan        rwd           front
# 197       gas  turbo         four        sedan        rwd           front
# 198       gas    std         four        sedan        rwd           front
# 199    diesel  turbo         four        sedan        rwd           front
# 200       gas  turbo         four        sedan        rwd           front
#
#       body_style engine_type num_of_cylinders fuel_system
# ...

# %%
# Exploring the categorical data

# %% [markdown]
# ### UNIVARIATE ANALYSIS ON CATEGORICAL DATA

# %%
sns.countplot(x='Fuel_type',data=df,palette='Dark2');

# %%
sns.countplot(x='make',data=df,palette='Dark2');

# %%
sns.countplot(x='num_of_doors',data=df,palette='Dark2');

# %%
sns.countplot(x='aspiration',data=df,palette='Dark2');

# %%
sns.countplot(x='wheel_base',data=df,palette='Dark2');

# %%
sns.countplot(x='engine_location',data=df,palette='Dark2');

# %%
sns.countplot(x='body_style',data=df,palette='Dark2')
plt.xticks(rotation=90);

# %%
sns.countplot(x='engine_type',data=df,palette='Dark2');

# %%
sns.countplot(x='num_of_cylinders',data=df,palette='Dark2');

# %%
sns.countplot(x='fuel_system',data=df,palette='Dark2')
# Out:
# <Axes: xlabel='fuel_system', ylabel='count'>

# %%
df.corr(numeric_only=True)['price'].sort_values()
# Out:
# highway_mpg         -0.704692
# city_mpg            -0.686571
# Unnamed: 0          -0.117889
# peak_rpm            -0.101542
# symboling           -0.082391
# compression_ratio    0.071107
# stroke               0.082209
# normalized_losses    0.093442
# height               0.135486
# bore                 0.543155
# drive_wheels         0.584642
# length               0.690628
# width                0.751265
# horsepower           0.810500
# curb_weight          0.834415
# engine_size          0.872335
# price                1.000000
# Name: price, dtype: float64

# %%
plt.figure(figsize=(12,10),dpi=150)
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'symboling', 'normalized_losses', 'Fuel_type', 'make',
#        'num_of_doors', 'aspiration', 'wheel_base', 'engine_location',
#        'drive_wheels', 'body_style', 'length', 'width', 'height',
#        'curb_weight', 'engine_type', 'num_of_cylinders', 'engine_size',
#        'fuel_system', 'bore', 'stroke', 'compression_ratio', 'horsepower',
#        'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df = df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#      symboling  normalized_losses Fuel_type   make num_of_doors   aspiration  \
# 0            3              115.0       gas    std          two  convertible
# 1            3              115.0       gas    std          two  convertible
# 2            1              115.0       gas    std          two    hatchback
# 3            2              164.0       gas    std         four        sedan
# 4            2              164.0       gas    std         four        sedan
# ..         ...                ...       ...    ...          ...          ...
# 196         -1               95.0       gas    std         four        sedan
# 197         -1               95.0       gas  turbo         four        sedan
# 198         -1               95.0       gas    std         four        sedan
# 199         -1               95.0    diesel  turbo         four        sedan
# 200         -1               95.0       gas  turbo         four        sedan
#
# ...

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'Fuel_type', 'make', 'num_of_doors',
#        'aspiration', 'wheel_base', 'engine_location', 'drive_wheels',
#        'body_style', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
sns.histplot(x='normalized_losses',data=df,kde=True)
# Out:
# <Axes: xlabel='normalized_losses', ylabel='Count'>

# %%
plt.
sns.pairplot(data=df)
